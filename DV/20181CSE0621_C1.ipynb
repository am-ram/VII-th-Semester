# %% [markdown]
# <h3>Sai Ram. K<br>20181CSE0621<br>7 - CSE - 10 <br>DV Batch - 1</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings; warnings.simplefilter('ignore')
import folium
from branca.element import Figure

# %%
fig=Figure(width=550,height=350)
area=folium.Map(location=[12.983377, 77.594167],tiles='cartodbpositron',zoom_start=11)

fig.add_child(area)
folium.Marker(location=[12.97796205124043, 77.5714694969577],popup='<strong>Majestic</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[12.996562101554806, 77.57708751303501],popup='<strong>Palace Guttahalli</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.016882272742771, 77.58358241093099],popup='<strong>Air Force</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.020493301901361, 77.5837421520479],popup='<strong>Mekhri Circle</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.050405525476947, 77.59265766860456],popup='<strong>Hebbal</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.057624213638528, 77.59282299744122],popup='<strong>Kodigehalli Gate</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.097844684714925, 77.59152868209517],popup='<strong>NES</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.134491394901266, 77.5692436149653],popup='<strong>Avalahalli</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.172811282800334, 77.56409842465821],popup='<strong>Rajanakunte</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)
folium.Marker(location=[13.171498731375447, 77.53504026495195],popup='<strong>Presidency University</strong>',
              tooltip='<strong>Click here to see Popup</strong>').add_to(area)

area
# Out:
# <iframe src="about:blank" width="550" height="350"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...
