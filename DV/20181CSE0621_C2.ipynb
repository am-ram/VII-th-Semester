# %% [markdown]
# <h3>Sai Ram. K<br>20181CSE0621<br>7 - CSE - 10 <br>DV Batch - 1</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings; warnings.simplefilter('ignore')
import folium
from branca.element import Figure

# %%
coords = [[13.061137332296994, 77.59140346409833],[13.098309650748288, 77.38255797179902],
          [13.06890397430386, 77.24358452868341],[13.004725327739276, 77.02016450710147],
          [12.968908480522032, 76.7227667258234],[12.909202280918393, 76.44207669847064],
          [12.787574713960845, 76.24603922736763],[12.61915424722405, 76.08230337112612],
          [12.575705754468608, 76.00703323162782],[12.491725848908086, 75.95292621931894],
          [12.457914905470735, 75.95996013380984],[12.429293239737179, 75.73807518007693]]

# %%
fig=Figure(height=550,width=750)
path=folium.Map(location=[13.057049892029676, 77.59334397946488],tiles='cartodbpositron',zoom_start=11)
fig.add_child(path)

f1=folium.FeatureGroup("TripRoute")
route=folium.vector_layers.PolyLine(coords,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
f1.add_to(path)
folium.LayerControl().add_to(path)

#Source and Destination
folium.Marker(location=[13.057049892029676, 77.59334397946488],popup='Kodigehalli-Bangalore',
              tooltip='<strong>Source</strong>',icon=folium.Icon(color='red',icon='none')).add_to(path)
folium.Marker(location=[12.484806330960296, 75.74588324974273],popup='Coorg',
              tooltip='<strong>Destination</strong>',icon=folium.Icon(color='green',icon='none')).add_to(path)
#Halts and Places visited
folium.Marker(location=[13.002008734310033, 77.02327674692559],popup='Kunigal',
              tooltip='<strong>Halt 1</strong>',icon=folium.Icon(color='purple',icon='none')).add_to(path)
folium.Marker(location=[12.980736014715502, 76.85806523648728],popup='Yediyur',
              tooltip='<strong>Halt 2</strong>',icon=folium.Icon(color='purple',icon='none')).add_to(path)
folium.Marker(location=[12.89907788851542, 76.38780245375803],popup='Channarayapatna',
              tooltip='<strong>Visit 1  </strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)
folium.Marker(location=[12.792076933697038, 76.24147226077902],popup='H.Nasipur',
              tooltip='<strong>Halt 3</strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)
folium.Marker(location=[12.621126616822222, 76.08511136445567],popup='RamanathPura',
              tooltip='<strong>Visit 2</strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)

folium.Marker(location=[12.957384454428588, 76.5802900223209],popup='Hirisave',
              tooltip='<strong>Halt 1</strong>',icon=folium.Icon(color='purple',icon='none')).add_to(path)
folium.Marker(location=[13.073759210960128, 77.20365744725231],popup='WoodStock Resort',
              tooltip='<strong>Halt 4</strong>',icon=folium.Icon(color='purple',icon='none')).add_to(path)
folium.Marker(location=[12.44301470843685, 75.84827332259593],popup='BirchWood Retreat',
              tooltip='<strong>Halt 5</strong>',icon=folium.Icon(color='purple',icon='none')).add_to(path)

folium.Marker(location=[12.596972959659393, 75.84791248779926],popup='Somvarpet',
              tooltip='<strong>Visit 3</strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)
folium.Marker(location=[12.416741161015432, 75.74568305754431],popup='Stuart Hill',
              tooltip='<strong>Visit 4</strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)
folium.Marker(location=[12.420714255397536, 75.7327807851114],popup='Adventure Club',
              tooltip='<strong>Visit 5</strong>',icon=folium.Icon(color='black',icon='none')).add_to(path)

path
# Out:
# <iframe src="about:blank" width="750" height="550"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...
